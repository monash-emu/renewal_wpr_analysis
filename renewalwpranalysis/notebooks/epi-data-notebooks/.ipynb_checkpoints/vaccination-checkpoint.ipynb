# %%
import pandas as pd
import plotly.express as px
from pathlib import Path

# %%
# Set general path
cwd = Path.cwd()

# %%
vax_data_path = cwd.parent.parent / Path("data/vaccination-data/vaccination_data_OWID.csv")
data = pd.read_csv(vax_data_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 vax_data_path = cwd.parent.parent / Path("data/vaccination-data/vaccination_data_OWID.csv")
# ----> 2 data = pd.read_csv(vax_data_path)
#
# ...

# %%
data
# Out:
#                                                COUNTRY ISO3 WHO_REGION  \
# 0                                                Aruba  ABW       AMRO
# 1                                          Afghanistan  AFG       EMRO
# 2                                               Angola  AGO       AFRO
# 3                                             Anguilla  AIA       AMRO
# 4                                              Albania  ALB       EURO
# ..                                                 ...  ...        ...
# 157  Kosovo (in accordance with UN Security Council...  XKX       EURO
# 158                                              Yemen  YEM       EMRO
# 159                                       South Africa  ZAF       AFRO
# 160                                             Zambia  ZMB       AFRO
# 161                                           Zimbabwe  ZWE       AFRO
#
#     DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 0     REPORTING   2023-12-29            217124.0
# ...

# %%
# select countries
countries = ['Malaysia','Philippines','Vietnam']

vax_df = data.loc[data['COUNTRY'].isin(countries)]

# %%
data['COUNTRY'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania', 'Andorra',
#        'Argentina', 'Armenia', 'Antigua and Barbuda', 'Australia',
#        'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin',
#        'Burkina Faso', 'Bulgaria', 'Bahamas', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia (Plurinational State of)',
#        'Brazil', 'Barbados', 'Botswana', 'Central African Republic',
#        'Canada', 'Switzerland', 'Chile', "Côte d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Cuba', 'Curaçao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt', 'Spain',
#        'Estonia', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'United Kingdom of Great Britain and Northern Ireland', 'Georgia',
# ...
